# %%
'''
NAME: ADITYA AGRAWAL
ROLL: 2311010
ASSIGN8: LAGUERRE's METHOD
DATE-08/10/2025
'''
# Out:
# "\nNAME: ADITYA AGRAWAL\nROLL: 2311010\nASSIGN8: LAGUERRE's METHOD\nDATE-08/10/2025\n"

# %%
import sys
import numpy as np
import matplotlib.pyplot as plt

sys.path.append('c:/Users/mayur/ClonedGitRepo/COMPUTATIONAL_PHYSICS/LABWORK')

import adilib_class as ad
import math

# %%
f1=lambda x: 1/x
f2=lambda x: (x*math.cos(x))
print("for  f1= 1/x")
print(ad.Integration.midpoint_integration(1,2,f1,790))
print(ad.Integration.simpson(1,2,f1,20))
print(.69314718,"_exact_")
print("\nfor f2  = xcosx")
print(ad.Integration.midpoint_integration(0,math.pi/2,f2,680))
print(ad.Integration.simpson(0,math.pi/2,f2,22))
print(math.pi/2 -1,"_exact_")
# Out:
# for  f1= 1/x
# 0.6931471304878586
# 0.6931473746651163
# 0.69314718 _exact_
#
# for f2  = xcosx
# 0.5707968983768099
# 0.570796987316687
# 0.5707963267948966 _exact_

# %%
f= lambda x : math.sin(x)**2
a,b,c,d=ad.Integration.montecarlo_diff(-1,1,f,10,10e-5)
print(1-math.sin(2)/2)
print(a,len(b),len(c))
print("N=",d)

ad.Visualization.plot(c,b,'Plot FN v/v N',"N","FN")
# Out:
# 0.5453512865871591
# 0.5452618764346039 243 243
# N= 4870
